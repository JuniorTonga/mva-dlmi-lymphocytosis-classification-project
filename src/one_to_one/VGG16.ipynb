# %% [markdown]
# # DLMI - Lymphocytosis classification
# ## One-to-one image model: VGG16

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn import metrics, model_selection
from torch.utils.data import DataLoader
from utils_pretrains import *

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
data_dir = "../../data/dlmi-lymphocytosis-classification/"
#data_dir = "/kaggle/input/dlmi-lymphocytosis/dlmi-lymphocytosis-classification/"
train_dir = data_dir + "trainset/"
test_dir = data_dir + "testset/"

# %%
train_val_images = load_images(train_dir)
test_images = load_images(test_dir)

# %%
trainset_true_df = pd.read_csv(data_dir + "trainset/trainset_true.csv")
labels_dict = dict(zip(trainset_true_df["ID"], trainset_true_df["LABEL"]))

# %%
id_train_val = list(train_val_images.keys())
id_train, id_val = model_selection.train_test_split(id_train_val, test_size=0.25)

train_images = {id: train_val_images[id] for id in id_train}
val_images = {id: train_val_images[id] for id in id_val}

X_train, y_train = assign_labels(train_images, labels_dict)
X_val, y_val = assign_labels(val_images, labels_dict)
len(X_train), len(X_val)
# Out:
# (10057, 3396)

# %%
transform_function = lambda x: x.reshape(3, x.shape[0], x.shape[1])

# %%
batch_size = 32
train_dataset = ImageLabelDataset(X_train, y_train, transform_function)
test_dataset = ImageLabelDataset(X_val, y_val, transform_function)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
class Classifier(nn.Module):

    def __init__(
        self,
        d_model=2048,
        num_classes=2
    ):
        super().__init__()
        self.d_model = d_model
        self.head = nn.Sequential(
            nn.Linear(d_model, 256),
            nn.ReLU(),
            nn.Linear(256, 64),
            nn.ReLU(),
            nn.Linear(64, num_classes)
        )

    def forward(self, x):
        x = self.head(x)
        return x

# %%
image_encoder = VGG16Encoder().to(device)
image_encoder.eval()
model = Classifier(d_model=25_088).to(device)
lr = 1e-2
optimizer = torch.optim.Adam(model.parameters(), lr=lr) 
loss_fn = nn.CrossEntropyLoss()

n_epochs = 50
trainer(
    model, image_encoder, optimizer, loss_fn, train_dataloader, test_dataloader, n_epochs,
    device=device, verbose=True, verbose_every=1, plot=True
)
# Out:
# [Epoch 1 / 50]
# 	train loss = 0.58806 acc = 0.80551 bacc = 0.50032
# 	test loss = 0.53404 acc = 0.77739 bacc = 0.50000
# [Epoch 2 / 50]
# 	train loss = 0.47685 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.53276 acc = 0.77739 bacc = 0.50000
# [Epoch 3 / 50]
# 	train loss = 0.47720 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.55523 acc = 0.77739 bacc = 0.50000
# [Epoch 4 / 50]
# 	train loss = 0.47537 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.53827 acc = 0.77739 bacc = 0.50000
# [Epoch 5 / 50]
# 	train loss = 0.47735 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54465 acc = 0.77739 bacc = 0.50000
# [Epoch 6 / 50]
# 	train loss = 0.47591 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54842 acc = 0.77739 bacc = 0.50000
# [Epoch 7 / 50]
# 	train loss = 0.47560 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54404 acc = 0.77739 bacc = 0.50000
# [Epoch 8 / 50]
# 	train loss = 0.47651 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54947 acc = 0.77739 bacc = 0.50000
# [Epoch 9 / 50]
# 	train loss = 0.47614 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54229 acc = 0.77739 bacc = 0.50000
# [Epoch 10 / 50]
# 	train loss = 0.47524 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54366 acc = 0.77739 bacc = 0.50000
# [Epoch 11 / 50]
# 	train loss = 0.47500 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54086 acc = 0.77739 bacc = 0.50000
# [Epoch 12 / 50]
# 	train loss = 0.47594 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54221 acc = 0.77739 bacc = 0.50000
# [Epoch 13 / 50]
# 	train loss = 0.47560 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.55034 acc = 0.77739 bacc = 0.50000
# [Epoch 14 / 50]
# 	train loss = 0.47573 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54228 acc = 0.77739 bacc = 0.50000
# [Epoch 15 / 50]
# 	train loss = 0.47599 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54487 acc = 0.77739 bacc = 0.50000
# [Epoch 16 / 50]
# 	train loss = 0.47541 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.55157 acc = 0.77739 bacc = 0.50000
# [Epoch 17 / 50]
# 	train loss = 0.47515 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54755 acc = 0.77739 bacc = 0.50000
# [Epoch 18 / 50]
# 	train loss = 0.47584 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54792 acc = 0.77739 bacc = 0.50000
# [Epoch 19 / 50]
# 	train loss = 0.47563 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.55149 acc = 0.77739 bacc = 0.50000
# [Epoch 20 / 50]
# 	train loss = 0.47614 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54359 acc = 0.77739 bacc = 0.50000
# [Epoch 21 / 50]
# 	train loss = 0.47496 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54223 acc = 0.77739 bacc = 0.50000
# [Epoch 22 / 50]
# 	train loss = 0.47579 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54377 acc = 0.77739 bacc = 0.50000
# [Epoch 23 / 50]
# 	train loss = 0.47592 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54152 acc = 0.77739 bacc = 0.50000
# [Epoch 24 / 50]
# 	train loss = 0.47627 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54942 acc = 0.77739 bacc = 0.50000
# [Epoch 25 / 50]
# 	train loss = 0.47558 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54365 acc = 0.77739 bacc = 0.50000
# [Epoch 26 / 50]
# 	train loss = 0.47540 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54616 acc = 0.77739 bacc = 0.50000
# [Epoch 27 / 50]
# 	train loss = 0.47606 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54176 acc = 0.77739 bacc = 0.50000
# [Epoch 28 / 50]
# 	train loss = 0.47593 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54332 acc = 0.77739 bacc = 0.50000
# [Epoch 29 / 50]
# 	train loss = 0.47547 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54017 acc = 0.77739 bacc = 0.50000
# [Epoch 30 / 50]
# 	train loss = 0.47626 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54676 acc = 0.77739 bacc = 0.50000
# [Epoch 31 / 50]
# 	train loss = 0.47531 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54987 acc = 0.77739 bacc = 0.50000
# [Epoch 32 / 50]
# 	train loss = 0.47536 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54614 acc = 0.77739 bacc = 0.50000
# [Epoch 33 / 50]
# 	train loss = 0.47609 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54905 acc = 0.77739 bacc = 0.50000
# [Epoch 34 / 50]
# 	train loss = 0.47564 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54256 acc = 0.77739 bacc = 0.50000
# [Epoch 35 / 50]
# 	train loss = 0.47497 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54357 acc = 0.77739 bacc = 0.50000
# [Epoch 36 / 50]
# 	train loss = 0.47607 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54317 acc = 0.77739 bacc = 0.50000
# [Epoch 37 / 50]
# 	train loss = 0.47536 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54358 acc = 0.77739 bacc = 0.50000
# [Epoch 38 / 50]
# 	train loss = 0.47533 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54412 acc = 0.77739 bacc = 0.50000
# [Epoch 39 / 50]
# 	train loss = 0.47614 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54435 acc = 0.77739 bacc = 0.50000
# [Epoch 40 / 50]
# 	train loss = 0.47510 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54254 acc = 0.77739 bacc = 0.50000
# [Epoch 41 / 50]
# 	train loss = 0.47621 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54493 acc = 0.77739 bacc = 0.50000
# [Epoch 42 / 50]
# 	train loss = 0.47541 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54191 acc = 0.77739 bacc = 0.50000
# [Epoch 43 / 50]
# 	train loss = 0.47577 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54857 acc = 0.77739 bacc = 0.50000
# [Epoch 44 / 50]
# 	train loss = 0.47470 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54330 acc = 0.77739 bacc = 0.50000
# [Epoch 45 / 50]
# 	train loss = 0.47609 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54222 acc = 0.77739 bacc = 0.50000
# [Epoch 46 / 50]
# 	train loss = 0.47571 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54151 acc = 0.77739 bacc = 0.50000
# [Epoch 47 / 50]
# 	train loss = 0.47606 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54176 acc = 0.77739 bacc = 0.50000
# [Epoch 48 / 50]
# 	train loss = 0.47543 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54465 acc = 0.77739 bacc = 0.50000
# [Epoch 49 / 50]
# 	train loss = 0.47574 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54445 acc = 0.77739 bacc = 0.50000
# [Epoch 50 / 50]
# 	train loss = 0.47575 acc = 0.81744 bacc = 0.50000
# 	test loss = 0.54425 acc = 0.77739 bacc = 0.50000

# %%
y_true_val = np.array([labels_dict[p] for p in val_images.keys()])
y_pred_min = predict_all(
    model, image_encoder, val_images, transform_function, batch_size=batch_size, 
    prediction_aggregator=PredictionAggregator.MIN, device=device
)
y_pred_max = predict_all(
    model, image_encoder, val_images, transform_function, batch_size=batch_size, 
    prediction_aggregator=PredictionAggregator.MAX, device=device
)
y_pred_mean = predict_all(
    model, image_encoder, val_images, transform_function, batch_size=batch_size, 
    prediction_aggregator=PredictionAggregator.MEAN, device=device
)

# %%
acc = metrics.accuracy_score(y_true_val, y_pred_min)
balanced_acc = metrics.balanced_accuracy_score(y_true_val, y_pred_min)
print(f"Min acc = {acc:.5f} bal. acc = {balanced_acc:.5f}")
acc = metrics.accuracy_score(y_true_val, y_pred_max)
balanced_acc = metrics.balanced_accuracy_score(y_true_val, y_pred_max)
print(f"Max acc = {acc:.5f} bal. acc = {balanced_acc:.5f}")
acc = metrics.accuracy_score(y_true_val, y_pred_mean)
balanced_acc = metrics.balanced_accuracy_score(y_true_val, y_pred_mean)
print(f"Mean acc = {acc:.5f} bal. acc = {balanced_acc:.5f}")
# Out:
# Min acc = 0.65854 bal. acc = 0.50000
# Max acc = 0.65854 bal. acc = 0.50000
# Mean acc = 0.65854 bal. acc = 0.50000
